# %%
import pandas as pd
CSV_PATH = "cleaned_data.csv"
df = pd.read_csv(CSV_PATH)
# Out:
# C:\Users\kirya\AppData\Local\Temp\ipykernel_28504\1453425465.py:3: DtypeWarning: Columns (0,12,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(CSV_PATH)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482238 entries, 0 to 482237
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   territory_code  482238 non-null  object
#  1   territory_name  482237 non-null  object
#  2   arrival_date    482237 non-null  object
#  3   trip_type       482237 non-null  object
#  4   visit_type      482237 non-null  object
#  5   home_country    482237 non-null  object
#  6   home_region     479143 non-null  object
#  7   home_city       320349 non-null  object
#  8   goal            482237 non-null  object
#  9   gender          478082 non-null  object
#  10  age_group       478082 non-null  object
#  11  income_group    478082 non-null  object
#  12  days_cnt        482237 non-null  object
#  13  visitors_cnt    482237 non-null  object
#  14  spent_mln       478082 non-null  object
# dtypes: object(15)
# memory usage: 55.2+ MB

# %%
print(df.isnull().sum())
# Out:
# territory_code         0
# territory_name         1
# arrival_date           1
# trip_type              1
# visit_type             1
# home_country           1
# home_region         3095
# home_city         161889
# goal                   1
# gender              4156
# age_group           4156
# income_group        4156
# days_cnt               1
# visitors_cnt           1
# spent_mln           4156
# dtype: int64

# %%
df
# Out:
#        territory_code         territory_name arrival_date  \
# 0            22701000  город Нижний Новгород   2021-01-19
# 1            22701000  город Нижний Новгород   2021-01-02
# 2            22701000  город Нижний Новгород   2021-01-08
# 3            22701000  город Нижний Новгород   2021-01-08
# 4            22701000  город Нижний Новгород   2021-01-17
# ...               ...                    ...          ...
# 482233       22701000  город Нижний Новгород   2021-06-14
# 482234       22701000  город Нижний Новгород   2021-06-10
# 482235       22701000  город Нижний Новгород   2021-06-22
# 482236       22701000  город Нижний Новгород   2021-06-23
# 482237                                  NaN          NaN
#
#                     trip_type  visit_type home_country            home_region  \
# 0       Поездка внутри страны      Турист       Россия  Нижегородская область
# 1       Поездка внутри страны      Турист       Россия  Нижегородская область
# ...

# %%
df[df['days_cnt'] == 'DAYS_CNT']
# Out:
#         territory_code  territory_name     arrival_date  trip_type  \
# 69592   TERRITORY_CODE  TERRITORY_NAME  DATE_OF_ARRIVAL  TRIP_TYPE
# 135094  TERRITORY_CODE  TERRITORY_NAME  DATE_OF_ARRIVAL  TRIP_TYPE
# 212484  TERRITORY_CODE  TERRITORY_NAME  DATE_OF_ARRIVAL  TRIP_TYPE
# 287299  TERRITORY_CODE  TERRITORY_NAME  DATE_OF_ARRIVAL  TRIP_TYPE
# 382561  TERRITORY_CODE  TERRITORY_NAME  DATE_OF_ARRIVAL  TRIP_TYPE
#
#         visit_type  home_country  home_region  home_city  goal  gender  \
# 69592   VISIT_TYPE  HOME_COUNTRY  HOME_REGION  HOME_CITY  GOAL  GENDER
# 135094  VISIT_TYPE  HOME_COUNTRY  HOME_REGION  HOME_CITY  GOAL  GENDER
# 212484  VISIT_TYPE  HOME_COUNTRY  HOME_REGION  HOME_CITY  GOAL  GENDER
# 287299  VISIT_TYPE  HOME_COUNTRY  HOME_REGION  HOME_CITY  GOAL  GENDER
# 382561  VISIT_TYPE  HOME_COUNTRY  HOME_REGION  HOME_CITY  GOAL  GENDER
#
#        age_group income_group  days_cnt  visitors_cnt spent_mln
# 69592        AGE       INCOME  DAYS_CNT  VISITORS_CNT     SPENT
# ...
